# %%
# Cell 1 - Imports
import numpy as np
import joblib
import librosa
import os

# Cell 2 - Load model
model_path = '../models/audio_score_model.pkl'
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Model not found at {model_path}")
model = joblib.load(model_path)
print("Model loaded successfully!")

# Cell 3 - Function to predict for one file
def predict_audio_score(file_path):
    if not os.path.exists(file_path):
        print(f" File not found: {file_path}")
        return None
    
    y, sr = librosa.load(file_path, sr=None)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    mfcc_mean = np.mean(mfcc.T, axis=0).reshape(1, -1)
    prediction = model.predict(mfcc_mean)[0]
    return prediction

# Cell 4 - Predict for all files in a test folder
test_folder = '../audio_data/audios_test/'
results = []

if not os.path.exists(test_folder):
    raise FileNotFoundError(f"Test folder not found: {test_folder}")

for filename in os.listdir(test_folder):
    if filename.endswith('.wav'):
        file_path = os.path.join(test_folder, filename)
        score = predict_audio_score(file_path)
        if score is not None:
            results.append((filename, score))
            print(f"🎧 {filename} → Predicted Score: {score:.2f}")

# Cell 5 - Save results to CSV (optional)
import pandas as pd
df_results = pd.DataFrame(results, columns=['filename', 'predicted_score'])
df_results.to_csv('../models/grammar.csv', index=False)
print(" All predictions saved to: ../models/grammar.csv")
# Out:
# Model loaded successfully!
# 🎧 audio_10.wav → Predicted Score: 3.71
# 🎧 audio_1012.wav → Predicted Score: 4.00
# 🎧 audio_1013.wav → Predicted Score: 3.97
# 🎧 audio_1019.wav → Predicted Score: 3.38
# 🎧 audio_1022.wav → Predicted Score: 3.42
# 🎧 audio_1026.wav → Predicted Score: 3.25
# 🎧 audio_103.wav → Predicted Score: 3.90
# 🎧 audio_1033.wav → Predicted Score: 3.23
# 🎧 audio_1035.wav → Predicted Score: 4.11
# 🎧 audio_1048.wav → Predicted Score: 2.32
# 🎧 audio_1054.wav → Predicted Score: 4.00
# 🎧 audio_1058.wav → Predicted Score: 3.50
# 🎧 audio_1061.wav → Predicted Score: 4.63
# 🎧 audio_1068.wav → Predicted Score: 4.38
# 🎧 audio_107.wav → Predicted Score: 3.79
# 🎧 audio_1081.wav → Predicted Score: 3.73
# 🎧 audio_1089.wav → Predicted Score: 3.94
# 🎧 audio_109.wav → Predicted Score: 3.75
# 🎧 audio_1091.wav → Predicted Score: 3.69
# 🎧 audio_1101.wav → Predicted Score: 3.88
# 🎧 audio_1115.wav → Predicted Score: 2.71
# 🎧 audio_1116.wav → Predicted Score: 2.69
# 🎧 audio_1122.wav → Predicted Score: 3.38
# 🎧 audio_1123.wav → Predicted Score: 3.02
# 🎧 audio_1124.wav → Predicted Score: 3.15
# 🎧 audio_113.wav → Predicted Score: 2.88
# 🎧 audio_1138.wav → Predicted Score: 3.77
# 🎧 audio_1159.wav → Predicted Score: 3.96
# 🎧 audio_1166.wav → Predicted Score: 3.51
# 🎧 audio_1169.wav → Predicted Score: 3.72
# 🎧 audio_1173.wav → Predicted Score: 3.61
# 🎧 audio_1176.wav → Predicted Score: 4.24
# 🎧 audio_1178.wav → Predicted Score: 4.18
# 🎧 audio_1179.wav → Predicted Score: 3.75
# 🎧 audio_1183.wav → Predicted Score: 3.34
# 🎧 audio_1190.wav → Predicted Score: 3.56
# 🎧 audio_1193.wav → Predicted Score: 3.65
# 🎧 audio_1195.wav → Predicted Score: 3.77
# 🎧 audio_1205.wav → Predicted Score: 3.02
# 🎧 audio_1214.wav → Predicted Score: 3.64
# 🎧 audio_1215.wav → Predicted Score: 3.79
# 🎧 audio_1217.wav → Predicted Score: 2.90
# 🎧 audio_1240.wav → Predicted Score: 2.95
# 🎧 audio_1242.wav → Predicted Score: 3.29
# 🎧 audio_1243.wav → Predicted Score: 4.07
# 🎧 audio_1256.wav → Predicted Score: 4.05
# 🎧 audio_1267.wav → Predicted Score: 3.75
# 🎧 audio_1275.wav → Predicted Score: 3.19
# 🎧 audio_1278.wav → Predicted Score: 2.85
# 🎧 audio_1280.wav → Predicted Score: 3.71
# 🎧 audio_1286.wav → Predicted Score: 3.44
# 🎧 audio_1289.wav → Predicted Score: 3.00
# 🎧 audio_1291.wav → Predicted Score: 3.73
# 🎧 audio_1292.wav → Predicted Score: 4.29
# 🎧 audio_1293.wav → Predicted Score: 3.81
# 🎧 audio_1297.wav → Predicted Score: 3.52
# 🎧 audio_1311.wav → Predicted Score: 3.04
# 🎧 audio_1315.wav → Predicted Score: 3.66
# 🎧 audio_1317.wav → Predicted Score: 3.78
# 🎧 audio_1321.wav → Predicted Score: 3.75
# 🎧 audio_1323.wav → Predicted Score: 3.15
# 🎧 audio_135.wav → Predicted Score: 3.63
# 🎧 audio_137.wav → Predicted Score: 3.98
# 🎧 audio_138.wav → Predicted Score: 3.28
# 🎧 audio_148.wav → Predicted Score: 3.73
# 🎧 audio_151.wav → Predicted Score: 4.11
# 🎧 audio_153.wav → Predicted Score: 3.65
# 🎧 audio_158.wav → Predicted Score: 4.29
# 🎧 audio_159.wav → Predicted Score: 3.82
# 🎧 audio_165.wav → Predicted Score: 4.29
# 🎧 audio_172.wav → Predicted Score: 3.57
# 🎧 audio_177.wav → Predicted Score: 3.27
# 🎧 audio_179.wav → Predicted Score: 3.75
# 🎧 audio_180.wav → Predicted Score: 3.29
# 🎧 audio_19.wav → Predicted Score: 3.28
# 🎧 audio_196.wav → Predicted Score: 4.07
# 🎧 audio_198.wav → Predicted Score: 3.46
# 🎧 audio_20.wav → Predicted Score: 3.86
# 🎧 audio_21.wav → Predicted Score: 3.96
# 🎧 audio_217.wav → Predicted Score: 3.92
# 🎧 audio_218.wav → Predicted Score: 3.83
# 🎧 audio_221.wav → Predicted Score: 3.17
# 🎧 audio_225.wav → Predicted Score: 3.60
# 🎧 audio_235.wav → Predicted Score: 3.79
# 🎧 audio_261.wav → Predicted Score: 4.01
# 🎧 audio_263.wav → Predicted Score: 4.13
# 🎧 audio_274.wav → Predicted Score: 3.35
# 🎧 audio_276.wav → Predicted Score: 3.46
# 🎧 audio_281.wav → Predicted Score: 3.71
# 🎧 audio_282.wav → Predicted Score: 3.58
# 🎧 audio_285.wav → Predicted Score: 3.77
# 🎧 audio_286.wav → Predicted Score: 4.30
# 🎧 audio_287.wav → Predicted Score: 3.73
# 🎧 audio_29.wav → Predicted Score: 3.38
# 🎧 audio_290.wav → Predicted Score: 3.21
# 🎧 audio_300.wav → Predicted Score: 3.89
# 🎧 audio_306.wav → Predicted Score: 3.96
# 🎧 audio_308.wav → Predicted Score: 4.00
# 🎧 audio_320.wav → Predicted Score: 3.87
# 🎧 audio_321.wav → Predicted Score: 3.89
# 🎧 audio_322.wav → Predicted Score: 2.56
# 🎧 audio_330.wav → Predicted Score: 3.92
# 🎧 audio_34.wav → Predicted Score: 3.23
# 🎧 audio_348.wav → Predicted Score: 3.92
# 🎧 audio_360.wav → Predicted Score: 3.38
# 🎧 audio_379.wav → Predicted Score: 4.54
# 🎧 audio_386.wav → Predicted Score: 4.22
# 🎧 audio_388.wav → Predicted Score: 3.88
# 🎧 audio_391.wav → Predicted Score: 3.65
# 🎧 audio_394.wav → Predicted Score: 4.11
# 🎧 audio_4.wav → Predicted Score: 3.84
# 🎧 audio_401.wav → Predicted Score: 4.04
# 🎧 audio_408.wav → Predicted Score: 3.65
# 🎧 audio_422.wav → Predicted Score: 4.05
# 🎧 audio_428.wav → Predicted Score: 4.11
# 🎧 audio_433.wav → Predicted Score: 3.86
# 🎧 audio_435.wav → Predicted Score: 4.00
# 🎧 audio_437.wav → Predicted Score: 3.12
# 🎧 audio_448.wav → Predicted Score: 4.35
# 🎧 audio_48.wav → Predicted Score: 3.88
# 🎧 audio_487.wav → Predicted Score: 4.46
# 🎧 audio_488.wav → Predicted Score: 3.90
# 🎧 audio_499.wav → Predicted Score: 3.94
# 🎧 audio_500.wav → Predicted Score: 3.24
# 🎧 audio_512.wav → Predicted Score: 4.29
# 🎧 audio_519.wav → Predicted Score: 4.12
# 🎧 audio_521.wav → Predicted Score: 4.42
# 🎧 audio_525.wav → Predicted Score: 3.74
# 🎧 audio_529.wav → Predicted Score: 3.73
# 🎧 audio_540.wav → Predicted Score: 3.65
# 🎧 audio_541.wav → Predicted Score: 3.13
# 🎧 audio_543.wav → Predicted Score: 3.59
# 🎧 audio_545.wav → Predicted Score: 3.02
# 🎧 audio_546.wav → Predicted Score: 3.34
# 🎧 audio_550.wav → Predicted Score: 3.58
# 🎧 audio_554.wav → Predicted Score: 4.38
# 🎧 audio_556.wav → Predicted Score: 3.50
# 🎧 audio_564.wav → Predicted Score: 3.51
# 🎧 audio_569.wav → Predicted Score: 3.17
# 🎧 audio_572.wav → Predicted Score: 3.50
# 🎧 audio_580.wav → Predicted Score: 3.47
# 🎧 audio_599.wav → Predicted Score: 3.44
# 🎧 audio_604.wav → Predicted Score: 3.69
# 🎧 audio_633.wav → Predicted Score: 3.34
# 🎧 audio_641.wav → Predicted Score: 3.21
# 🎧 audio_644.wav → Predicted Score: 2.69
# 🎧 audio_656.wav → Predicted Score: 3.56
# 🎧 audio_66.wav → Predicted Score: 3.92
# 🎧 audio_662.wav → Predicted Score: 3.98
# 🎧 audio_665.wav → Predicted Score: 3.62
# 🎧 audio_676.wav → Predicted Score: 3.67
# 🎧 audio_68.wav → Predicted Score: 3.75
# 🎧 audio_683.wav → Predicted Score: 3.02
# 🎧 audio_690.wav → Predicted Score: 3.04
# 🎧 audio_692.wav → Predicted Score: 3.28
# 🎧 audio_698.wav → Predicted Score: 2.98
# 🎧 audio_702.wav → Predicted Score: 3.98
# 🎧 audio_706.wav → Predicted Score: 3.18
# 🎧 audio_709.wav → Predicted Score: 3.56
# 🎧 audio_713.wav → Predicted Score: 3.94
# 🎧 audio_719.wav → Predicted Score: 3.31
# 🎧 audio_72.wav → Predicted Score: 3.94
# 🎧 audio_726.wav → Predicted Score: 3.17
# 🎧 audio_733.wav → Predicted Score: 3.83
# 🎧 audio_735.wav → Predicted Score: 2.85
# 🎧 audio_746.wav → Predicted Score: 3.46
# 🎧 audio_75.wav → Predicted Score: 3.47
# 🎧 audio_759.wav → Predicted Score: 3.81
# 🎧 audio_762.wav → Predicted Score: 3.90
# 🎧 audio_767.wav → Predicted Score: 3.21
# 🎧 audio_770.wav → Predicted Score: 3.07
# 🎧 audio_800.wav → Predicted Score: 2.85
# 🎧 audio_805.wav → Predicted Score: 2.67
# 🎧 audio_811.wav → Predicted Score: 3.62
# 🎧 audio_820.wav → Predicted Score: 3.67
# 🎧 audio_831.wav → Predicted Score: 2.86
# 🎧 audio_841.wav → Predicted Score: 3.12
# 🎧 audio_857.wav → Predicted Score: 3.75
# 🎧 audio_858.wav → Predicted Score: 3.44
# 🎧 audio_882.wav → Predicted Score: 3.73
# 🎧 audio_884.wav → Predicted Score: 4.14
# 🎧 audio_885.wav → Predicted Score: 3.12
# 🎧 audio_888.wav → Predicted Score: 3.94
# 🎧 audio_89.wav → Predicted Score: 3.46
# 🎧 audio_897.wav → Predicted Score: 4.16
# 🎧 audio_908.wav → Predicted Score: 3.58
# 🎧 audio_920.wav → Predicted Score: 3.21
# 🎧 audio_922.wav → Predicted Score: 3.44
# 🎧 audio_932.wav → Predicted Score: 3.95
# 🎧 audio_949.wav → Predicted Score: 3.56
# 🎧 audio_95.wav → Predicted Score: 3.86
# 🎧 audio_958.wav → Predicted Score: 3.45
# 🎧 audio_959.wav → Predicted Score: 3.92
# 🎧 audio_971.wav → Predicted Score: 3.07
# 🎧 audio_998.wav → Predicted Score: 3.29
#  All predictions saved to: ../models/grammar.csv
